# %%
import os 
import re

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
path = 'Data/binance'
data = pd.DataFrame()

for file_name in os.listdir(path):
    coin = file_name[:-4] 
    df = pd.read_csv(f'{path}/{file_name}')
    df['open_time'] = pd.to_datetime(df['open_time'], unit='ms')
    df['coin'] = coin
    data = pd.concat([data, df])

# %%
data = data.sort_values(by='open_time').reset_index(drop=True)
data.loc[:, 'coin'] = data.coin.apply(lambda x: re.sub('_[0-9]+', '', x))
data
# Out:
#         open_time        open        high         low       close
# 0      2019-12-31   131.53000   133.64000   128.15000   129.12000  \
# 1      2019-12-31  7240.80000  7319.00000  7141.00000  7189.00000
# 2      2019-12-31   208.45000   214.00000   201.73000   204.72000
# 3      2020-01-01   129.12000   132.96000   128.62000   130.62000
# 4      2020-01-01  7189.43000  7260.43000  7170.15000  7197.57000
# ...           ...         ...         ...         ...         ...
# 102086 2023-07-31     0.04542     0.04542     0.04542     0.04542
# 102087 2023-07-31     0.62530     0.63300     0.61480     0.62380
# 102088 2023-07-31    21.02000    21.02000    21.02000    21.02000
# 102089 2023-07-31     0.59060     0.59670     0.57400     0.58130
# 102090 2023-07-31     0.99949     0.99970     0.99948     0.99969
#
#               volume     close_time  quote_volume   count  taker_buy_volume
# 0       6.477434e+05  1577836799999  8.461409e+07   54948      3.135559e+05  \
# 1       8.920344e+04  1577836799999  6.437921e+08  157014      4.288085e+04
# 2       3.208150e+05  1577836799999  6.671133e+07   46150      1.595145e+05
# 3       4.660639e+05  1577923199999  6.103756e+07   40168      2.324929e+05
# 4       5.680133e+04  1577923199999  4.096788e+08  101871      2.883420e+04
# ...              ...            ...           ...     ...               ...
# 102086  0.000000e+00  1690847999999  0.000000e+00       0      0.000000e+00
# 102087  5.485799e+06  1690847999999  3.438098e+06   32635      2.628786e+06
# 102088  0.000000e+00  1690847999999  0.000000e+00       0      0.000000e+00
# 102089  2.195960e+07  1690847999999  1.286633e+07   72080      1.062750e+07
# 102090  6.414780e+05  1690847999999  6.412305e+05    4215      3.572240e+05
#
#         taker_buy_quote_volume  ignore       coin
# 0                 4.096389e+07       0    ETHUSDT
# 1                 3.095523e+08       0    BTCUSDT
# 2                 3.316821e+07       0    BCHUSDT
# 3                 3.044614e+07       0    ETHUSDT
# 4                 2.080020e+08       0    BTCUSDT
# ...                        ...     ...        ...
# 102086            0.000000e+00       0    ANCBUSD
# 102087            1.648222e+06       0  COMBOUSDT
# 102088            0.000000e+00       0   AVAXBUSD
# 102089            6.231102e+06       0  LUNA2USDT
# 102090            3.570803e+05       0   USDCUSDT
#
# [102091 rows x 13 columns]

# %%
data.to_pickle('Data/binance_futures.pickle')
