# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle("Data\cmktcap_data_raw.pickle")

price = pd.pivot_table(data=data, values="close",
                       index=data.index,columns="coin_id")

# %%
# Load file that mapping from coin_id to symbol
coin_list = pd.read_csv("Data/coin_list_coinmarketcap.csv", index_col=0)[["id","symbol"]]
coin_list.id = coin_list.id.astype("str")
coin_list.head()
# Out:
#   id symbol
# 0  1    BTC
# 1  2    LTC
# 2  3    NMC
# 3  4    TRC
# 4  5    PPC

# %%
stable_coin = ["USDT","USDC","BUSD","DAI","TUSD",
               "FRAX","USDP","USDD","GUSD","FEI","USDJ","LUSD",
               "USTC","EURS","TRIBE","vUSDC","USDX",
               "vBUSD","XSGD","VAI","SUSD","CUSD","SBD",
               "vUSDT","EUROC","OUSD","USDK","RSV","KRT",
               "GYEN","CEUR","HUSD","BIDR","IDRT","vDAI",
               "DGD","BITCNY","XCHF","DGX","EOSDT","BITUSD",
               "ZUSD","ESD","USDS","BAC","ALUSD","YUSD",
               "USX","MIM","DOLA","MIMATIC","EURT","MUSD",
               "USDs","AGEUR","mCUSD","TOR","TRYB","mCEUR",
               "XIDR","1GOLD","USDS","MXNT","XSTUSD","USDEX",
               "CUSD","MTR","BRCP","CUSDT","SEUR","xDAI",
               "DUSD","USDP","USDH","USDZ","DJED","JPYC",
               "PAR","WANUSDT","ONC","FUSD","MUSD","ONEICHI",
               "FUSD","CADC","XUSD","DSD","JPYC","USDB","XUSD",
               "MONEY","USDR","COFFIN","IRON","KBC","DPT","nUSD",
               "STATIK","USN","USNBT","BITGOLD","BITEUR","HGT",
               "QC","ITL","CONST","USDQ","XEUR","BGBP","EBASE",
               "BKRW","USDEX","USDL","UETH","BVND","BSD","SAC",
               "USDEX","ZUSD","USDFL","MDS","MDO","FLOAT","fUSDT",
               "FLUSD","ARTH","USDAP","BEAN","COUSD","DUSD","AUSD",
               "fUSDT","H2O","IUSDS","USDI","GBPT","EUROS"]
len(stable_coin)
# Out:
# 137

# %%
catch_stable = []

for columns in price.columns:
    symbol = coin_list.loc[coin_list.id == columns, "symbol"].values[0]
    if symbol in stable_coin: 
        catch_stable.append(columns) # If symbol is match, than save id

# %%
stable = data.loc[(data.coin_id.apply(lambda x: x in catch_stable).values)]

# %%
stable
# Out:
#            coin_id      open      high           low         close
# date
# 2014-03-12     162  0.000005  0.000006  1.514980e-06  5.816800e-06  \
# 2014-03-13     162  0.000006  0.000006  1.326960e-06  5.252200e-06
# 2014-03-14     162  0.000005  0.000007  2.602420e-06  3.001100e-06
# 2014-03-15     162  0.000003  0.000003  8.164080e-07  1.866800e-06
# 2014-03-16     162  0.000002  0.000002  4.909320e-07  4.922000e-07
# ...            ...       ...       ...           ...           ...
# 2023-04-16   10789  1.100533  1.102708  1.097521e+00  1.099940e+00
# 2023-04-16   10484  0.000108  0.000114  1.004555e-04  1.132228e-04
# 2023-04-16     366  0.000546  0.000550  5.434051e-04  5.457581e-04
# 2023-04-16   10419  1.077713  1.086713  1.074967e+00  1.076843e+00
# 2023-04-16   10238  0.997638  0.999891  9.891930e-01  9.979305e-01
#
#                      vol        mktcap                  timehigh
# date
13       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-16       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-12  0.007513  0.994750  0.999719  0.285180  0.007957  1.089314
# 2023-04-13  0.007587  0.994750  1.000652  0.304626  0.008163  1.093382
# 2023-04-14  0.007510  0.994750  0.999608  0.308598  0.008208  1.094583
# 2023-04-15  0.007486  0.994750  0.999252  0.307836  0.008234  1.090299
# 2023-04-16  0.007466  0.993914  0.998897  0.307535  0.008220  1.092645
#
# coin_id         9566
# date
# 2014-03-12       NaN
# 2014-03-13       NaN
# 2014-03-14       NaN
# 2014-03-15       NaN
# 2014-03-16       NaN
# ...              ...
# 2023-04-12  1.010631
# 2023-04-13  1.013463
# 2023-04-14  1.014266
# 2023-04-15  1.012921
# 2023-04-16  1.012022
#
# [3323 rows x 129 columns]

# %%
price.pct_change(fill_method=None)
# Out:
# coin_id        10238     10419     10484     10789  1158      1229     12366
# date
# 2014-03-12       NaN       NaN       NaN       NaN   NaN       NaN       NaN  \
# 2014-03-13       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2014-03-14       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2014-03-15       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 2014-03-16       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# ...              ...       ...       ...       ...   ...       ...       ...
# 2023-04-12 -0.000307  0.008800  0.030130  0.007814   NaN  0.000234 -0.008096
# 2023-04-13  0.001859 -0.021232  0.022893  0.002927   NaN  0.007940  0.004344
# 2023-04-14 -0.002383  0.002359 -0.032367 -0.003392   NaN  0.006687  0.013952
# 2023-04-15  0.000261 -0.001986 -0.012540  0.000228   NaN -0.114626  0.002740
# 2023-04-16  0.000373 -0.000816  0.048910 -0.000567   NaN -0.000037  0.002034
#
# coin_id        12439     12765     12840  ...      8657      8665      8690
# date                                      ...
# 2014-03-12       NaN       NaN       NaN  ...       NaN       NaN       NaN  \
# 2014-03-13       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2014-03-14       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2014-03-15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 2014-03-16       NaN       NaN       NaN  ...       NaN       NaN       NaN
# ...              ...       ...       ...  ...       ...       ...       ...
# 2023-04-12 -0.000339 -0.007682 -0.022793  ... -0.003294  0.003828 -0.595977
# 2023-04-13  0.000551  0.000435  0.023620  ... -0.000789  0.004493  1.481266
# 2023-04-14 -0.000150  0.000000  0.003400  ...  0.004398  0.001571 -0.000639
# 2023-04-15 -0.000039  0.121445 -0.008294  ... -0.002662 -0.001884  0.010198
# 2023-04-16 -0.000351  0.033211  0.021910  ... -0.000148 -0.001049  0.012939
#
# coin_id         8771      8772      8886      9025      9045      9467
# date
# 2014-03-12       NaN       NaN       NaN       NaN       NaN       NaN  \
# 2014-03-13       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2014-03-16       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-12  0.000827  0.000225  0.000120 -0.002233  0.004478  0.005003
# 2023-04-13  0.009843  0.000000  0.000933  0.068190  0.025877  0.003734
# 2023-04-14 -0.010064  0.000000 -0.001044  0.013039  0.005415  0.001098
# 2023-04-15 -0.003273  0.000000 -0.000356 -0.002469  0.003180 -0.003913
# 2023-04-16 -0.002660 -0.000841 -0.000355 -0.000978 -0.001650  0.002151
#
# coin_id         9566
# date
# 2014-03-12       NaN
# 2014-03-13       NaN
# 2014-03-14       NaN
# 2014-03-15       NaN
# 2014-03-16       NaN
# ...              ...
# 2023-04-12 -0.000370
# 2023-04-13  0.002803
# 2023-04-14  0.000792
# 2023-04-15 -0.001326
# 2023-04-16 -0.000888
#
# [3323 rows x 129 columns]
