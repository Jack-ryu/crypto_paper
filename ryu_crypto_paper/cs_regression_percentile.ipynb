# %%
import numpy as np 
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt

import statsmodels.api as sm
from tqdm import tqdm

from multi_run_v3.data_pp import DataPreprocess
from multi_run_v3.momentum_strategy_group import *
# Out:
# 2023-09-03 10:06:50,227	INFO worker.py:1625 -- Started a local Ray instance.

# %%
data = pd.read_pickle("Data/cmc_final_data.pickle")
days_lst = ["MON","TUE","WED","THU","FRI","SAT","SUN"]

data_pp = DataPreprocess()
data_pp.initialize(data=data)
data_pp.make_mask(mktcap_thresh=1_000_000,
                  vol_thresh=1_000_000,
                  ma=True)

# %%
def make_group_percentile(
    price_df:pd.DataFrame, 
    weekly_rtn_df:pd.DataFrame,
    mask_df:pd.DataFrame,
    n_group:int,
    day_of_week:str,
    reb:str = '1',# 1이면 일주일, 2이면 2주일 간격 리벨런싱
    look_back:int = 7,
    coin_group:int = 20
    ): 
    '''
    그룹의 마스크를 반환합니다

        n_group : 몇 개의 그룹으로 나눌 지
        day_of_week : Rebalancing을 진행할 요일 [MON,TUE,WED,THU,FRI,SAT,SUN]
    '''
    last_day = price_df.index[-1]
    
    weekly_mask = mask_df.resample(reb + "W-" + day_of_week).last()[:last_day]
    
    if look_back != 7:
        weekly_rtn_df = price_df.pct_change(look_back, fill_method=None)
    
    weekly_rtn = weekly_rtn_df.resample(reb + "W-" + day_of_week).last()[:last_day]
    weekly_rtn_masked = weekly_rtn * weekly_mask 
        
    # 언제부터 시작하는 지 (최소 q*n개의 코인이 필요)
    cnt = weekly_rtn_masked.count(1)
    thresh = cnt[cnt >= (n_group * coin_group)] # 여기서 start date가 나온다 / 각 그룹당 최소 20개의 코인이 필요함
    strategy_start = thresh.index[0] 
        
    # rank 계산
    pct_df = weekly_rtn_masked[strategy_start:].rank(axis=1, method="first", pct=True)
    return pct_df

# %%
# constant 있는 결과
holding = [1,2,3,4,5,6,7,8]
look_back_list = [i * 7 for i in holding]

for reb in holding:
    for look_back in look_back_list:
        reb = str(reb)
        #for day in days_lst:
        pct_df = make_group_percentile(
            price_df = data_pp.price_df,
            weekly_rtn_df = data_pp.weekly_rtn_df, 
            mask_df = data_pp.mask,
            n_group = 5,
            day_of_week = 'FRI',
            coin_group=20,
            look_back=look_back,
            reb=reb
        )

        d = pd.concat([pct_df.melt(), pct_df.shift(-1).melt()], axis=1).iloc[:, [0,1,3]].dropna()
        d.columns = ['coin_id', 'x', 'y']
    
        #all_df = pd.concat([all_df, d])
    
        ols =  sm.OLS(d.y, sm.add_constant(d.x))
        result = ols.fit()
        print("future-week:", reb, "look-back windows (days):",  look_back)
        print(f'Constant: {result.params[0].round(4)},  Coef: {result.params[1].round(4)}')
        print(f'T-stat for Constant: {result.tvalues[0].round(4)}, T-stat for Coef: {result.tvalues[1].round(4)}')
# Out:
# future-week: 1 look-back windows (days): 7
# Constant: 0.5074,  Coef: -0.018
# T-stat for Constant: 305.496, T-stat for Coef: -6.2738
# future-week: 1 look-back windows (days): 14
# Constant: 0.2749,  Coef: 0.4409
# T-stat for Constant: 184.4338, T-stat for Coef: 171.7403
# future-week: 1 look-back windows (days): 21
# Constant: 0.1943,  Coef: 0.5997
# T-stat for Constant: 146.0144, T-stat for Coef: 262.0581
# future-week: 1 look-back windows (days): 28
# Constant: 0.1476,  Coef: 0.6904
# T-stat for Constant: 122.437, T-stat for Coef: 333.4546
# future-week: 1 look-back windows (days): 35
# Constant: 0.1214,  Coef: 0.7436
# T-stat for Constant: 108.5337, T-stat for Coef: 386.838
# future-week: 1 look-back windows (days): 42
# Constant: 0.1023,  Coef: 0.7839
# T-stat for Constant: 98.5868, T-stat for Coef: 438.6651
# future-week: 1 look-back windows (days): 49
# Constant: 0.0892,  Coef: 0.8116
# T-stat for Constant: 91.079, T-stat for Coef: 481.2265
# future-week: 1 look-back windows (days): 56
# Constant: 0.0799,  Coef: 0.831
# T-stat for Constant: 85.5726, T-stat for Coef: 516.6665
# future-week: 2 look-back windows (days): 7
# Constant: 0.4934,  Coef: 0.0134
# T-stat for Constant: 210.9918, T-stat for Coef: 3.334
# future-week: 2 look-back windows (days): 14
# Constant: 0.5015,  Coef: -0.0103
# T-stat for Constant: 214.32, T-stat for Coef: -2.5622
# future-week: 2 look-back windows (days): 21
# Constant: 0.347,  Coef: 0.2907
# T-stat for Constant: 154.578, T-stat for Coef: 75.5294
# future-week: 2 look-back windows (days): 28
# Constant: 0.2697,  Coef: 0.4409
# T-stat for Constant: 127.5453, T-stat for Coef: 121.9079
# future-week: 2 look-back windows (days): 35
# Constant: 0.2233,  Coef: 0.5316
# T-stat for Constant: 111.3334, T-stat for Coef: 155.0872
# future-week: 2 look-back windows (days): 42
# Constant: 0.1931,  Coef: 0.594
# T-stat for Constant: 101.5108, T-stat for Coef: 182.235
# future-week: 2 look-back windows (days): 49
# Constant: 0.1641,  Coef: 0.6542
# T-stat for Constant: 91.657, T-stat for Coef: 212.8584
# future-week: 2 look-back windows (days): 56
# Constant: 0.1489,  Coef: 0.6857
# T-stat for Constant: 86.3432, T-stat for Coef: 231.4245
# future-week: 3 look-back windows (days): 7
# Constant: 0.4937,  Coef: 0.015
# T-stat for Constant: 172.9588, T-stat for Coef: 3.057
# future-week: 3 look-back windows (days): 14
# Constant: 0.4923,  Coef: 0.0119
# T-stat for Constant: 172.2406, T-stat for Coef: 2.434
# future-week: 3 look-back windows (days): 21
# Constant: 0.5043,  Coef: -0.0178
# T-stat for Constant: 176.0317, T-stat for Coef: -3.6237
# future-week: 3 look-back windows (days): 28
# Constant: 0.3883,  Coef: 0.2049
# T-stat for Constant: 137.7378, T-stat for Coef: 42.5974
# future-week: 3 look-back windows (days): 35
# Constant: 0.3217,  Coef: 0.3337
# T-stat for Constant: 118.0239, T-stat for Coef: 71.8253
# future-week: 3 look-back windows (days): 42
# Constant: 0.2759,  Coef: 0.4243
# T-stat for Constant: 105.0865, T-stat for Coef: 94.7517
# future-week: 3 look-back windows (days): 49
# Constant: 0.2391,  Coef: 0.4986
# T-stat for Constant: 95.0405, T-stat for Coef: 115.9391
# future-week: 3 look-back windows (days): 56
# Constant: 0.2133,  Coef: 0.5518
# T-stat for Constant: 88.1226, T-stat for Coef: 133.0979
# future-week: 4 look-back windows (days): 7
# Constant: 0.4967,  Coef: 0.0117
# T-stat for Constant: 150.7095, T-stat for Coef: 2.0599
# future-week: 4 look-back windows (days): 14
# Constant: 0.4983,  Coef: 0.0047
# T-stat for Constant: 151.2967, T-stat for Coef: 0.8373
# future-week: 4 look-back windows (days): 21
# Constant: 0.4983,  Coef: -0.0016
# T-stat for Constant: 150.9059, T-stat for Coef: -0.2867
# future-week: 4 look-back windows (days): 28
# Constant: 0.5063,  Coef: -0.0246
# T-stat for Constant: 152.6661, T-stat for Coef: -4.349
# future-week: 4 look-back windows (days): 35
# Constant: 0.4141,  Coef: 0.1514
# T-stat for Constant: 125.3164, T-stat for Coef: 26.9595
# future-week: 4 look-back windows (days): 42
# Constant: 0.3545,  Coef: 0.2667
# T-stat for Constant: 109.7321, T-stat for Coef: 48.5764
# future-week: 4 look-back windows (days): 49
# Constant: 0.3117,  Coef: 0.3517
# T-stat for Constant: 99.0109, T-stat for Coef: 65.6355
# future-week: 4 look-back windows (days): 56
# Constant: 0.278,  Coef: 0.4203
# T-stat for Constant: 91.1791, T-stat for Coef: 80.7853
# future-week: 5 look-back windows (days): 7
# Constant: 0.497,  Coef: 0.0145
# T-stat for Constant: 135.8497, T-stat for Coef: 2.2993
# future-week: 5 look-back windows (days): 14
# Constant: 0.5108,  Coef: -0.0159
# T-stat for Constant: 139.4647, T-stat for Coef: -2.5351
# future-week: 5 look-back windows (days): 21
# Constant: 0.5094,  Coef: -0.0192
# T-stat for Constant: 138.957, T-stat for Coef: -3.0607
# future-week: 5 look-back windows (days): 28
# Constant: 0.5111,  Coef: -0.0264
# T-stat for Constant: 138.7917, T-stat for Coef: -4.2115
# future-week: 5 look-back windows (days): 35
# Constant: 0.5203,  Coef: -0.0518
# T-stat for Constant: 139.8851, T-stat for Coef: -8.2123
# future-week: 5 look-back windows (days): 42
# Constant: 0.4358,  Coef: 0.1097
# T-stat for Constant: 117.1721, T-stat for Coef: 17.3736
# future-week: 5 look-back windows (days): 49
# Constant: 0.3827,  Coef: 0.2119
# T-stat for Constant: 104.3452, T-stat for Coef: 34.0066
# future-week: 5 look-back windows (days): 56
# Constant: 0.3393,  Coef: 0.2963
# T-stat for Constant: 94.5872, T-stat for Coef: 48.5311
# future-week: 6 look-back windows (days): 7
# Constant: 0.5011,  Coef: 0.0069
# T-stat for Constant: 125.5984, T-stat for Coef: 0.998
# future-week: 6 look-back windows (days): 14
# Constant: 0.4958,  Coef: 0.0129
# T-stat for Constant: 124.4897, T-stat for Coef: 1.884
# future-week: 6 look-back windows (days): 21
# Constant: 0.4983,  Coef: 0.005
# T-stat for Constant: 124.8298, T-stat for Coef: 0.7365
# future-week: 6 look-back windows (days): 28
# Constant: 0.5121,  Coef: -0.027
# T-stat for Constant: 127.7064, T-stat for Coef: -3.9477
# future-week: 6 look-back windows (days): 35
# Constant: 0.5184,  Coef: -0.044
# T-stat for Constant: 128.2105, T-stat for Coef: -6.4042
# future-week: 6 look-back windows (days): 42
# Constant: 0.5207,  Coef: -0.0514
# T-stat for Constant: 128.2427, T-stat for Coef: -7.474
# future-week: 6 look-back windows (days): 49
# Constant: 0.4557,  Coef: 0.0696
# T-stat for Constant: 111.8338, T-stat for Coef: 10.0766
# future-week: 6 look-back windows (days): 56
# Constant: 0.4047,  Coef: 0.1667
# T-stat for Constant: 100.4258, T-stat for Coef: 24.3544
# future-week: 7 look-back windows (days): 7
# Constant: 0.5005,  Coef: 0.0107
# T-stat for Constant: 116.2248, T-stat for Coef: 1.4455
# future-week: 7 look-back windows (days): 14
# Constant: 0.499,  Coef: 0.0113
# T-stat for Constant: 115.811, T-stat for Coef: 1.5329
# future-week: 7 look-back windows (days): 21
# Constant: 0.4971,  Coef: 0.01
# T-stat for Constant: 115.1728, T-stat for Coef: 1.3599
# future-week: 7 look-back windows (days): 28
# Constant: 0.5013,  Coef: -0.0004
# T-stat for Constant: 115.7078, T-stat for Coef: -0.0567
# future-week: 7 look-back windows (days): 35
# Constant: 0.5161,  Coef: -0.0325
# T-stat for Constant: 118.3406, T-stat for Coef: -4.3965
# future-week: 7 look-back windows (days): 42
# Constant: 0.5252,  Coef: -0.0539
# T-stat for Constant: 120.0316, T-stat for Coef: -7.2776
# future-week: 7 look-back windows (days): 49
# Constant: 0.5404,  Coef: -0.0872
# T-stat for Constant: 123.3621, T-stat for Coef: -11.7457
# future-week: 7 look-back windows (days): 56
# Constant: 0.473,  Coef: 0.0407
# T-stat for Constant: 107.1938, T-stat for Coef: 5.444
# future-week: 8 look-back windows (days): 7
# Constant: 0.4898,  Coef: 0.037
# T-stat for Constant: 107.5996, T-stat for Coef: 4.7353
# future-week: 8 look-back windows (days): 14
# Constant: 0.4977,  Coef: 0.0187
# T-stat for Constant: 109.3495, T-stat for Coef: 2.398
# future-week: 8 look-back windows (days): 21
# Constant: 0.5017,  Coef: 0.0061
# T-stat for Constant: 109.7314, T-stat for Coef: 0.7836
# future-week: 8 look-back windows (days): 28
# Constant: 0.5114,  Coef: -0.0169
# T-stat for Constant: 111.5402, T-stat for Coef: -2.1701
# future-week: 8 look-back windows (days): 35
# Constant: 0.5151,  Coef: -0.0322
# T-stat for Constant: 111.2533, T-stat for Coef: -4.1047
# future-week: 8 look-back windows (days): 42
# Constant: 0.5116,  Coef: -0.0288
# T-stat for Constant: 109.9516, T-stat for Coef: -3.6573
# future-week: 8 look-back windows (days): 49
# Constant: 0.5129,  Coef: -0.0324
# T-stat for Constant: 109.9347, T-stat for Coef: -4.1076
# future-week: 8 look-back windows (days): 56
# Constant: 0.5172,  Coef: -0.0446
# T-stat for Constant: 110.3446, T-stat for Coef: -5.6297

# %%
# constant 없는 결과
holding = [1,2,3,4,5,6,7,8]
look_back_list = [i * 7 for i in holding]

for reb in holding:
    for look_back in look_back_list:
        reb = str(reb)
        #for day in days_lst:
        pct_df = make_group_percentile(
            price_df = data_pp.price_df,
            weekly_rtn_df = data_pp.weekly_rtn_df, 
            mask_df = data_pp.mask,
            n_group = 5,
            day_of_week = 'FRI',
            coin_group=20,
            look_back=look_back,
            reb=reb
        )

        d = pd.concat([pct_df.melt(), pct_df.shift(-1).melt()], axis=1).iloc[:, [0,1,3]].dropna()
        d.columns = ['coin_id', 'x', 'y']
    
        #all_df = pd.concat([all_df, d])
    
        ols =  sm.OLS(d.y, (d.x))
        result = ols.fit()
        print("future-week:", reb, "look-back windows (days):",  look_back)
        print(f'Coef: {result.params[0].round(4)}')
        print(f'T-stat for Coef: {result.tvalues[0].round(4)}')
# Out:
# future-week: 1 look-back windows (days): 7
# Coef: 0.7412
# T-stat for Coef: 390.2491
# future-week: 1 look-back windows (days): 14
# Coef: 0.8519
# T-stat for Coef: 590.0606
# future-week: 1 look-back windows (days): 21
# Coef: 0.8899
# T-stat for Coef: 723.4736
# future-week: 1 look-back windows (days): 28
# Coef: 0.9108
# T-stat for Coef: 839.3947
# future-week: 1 look-back windows (days): 35
# Coef: 0.925
# T-stat for Coef: 929.2402
# future-week: 1 look-back windows (days): 42
# Coef: 0.937
# T-stat for Coef: 1018.182
# future-week: 1 look-back windows (days): 49
# Coef: 0.945
# T-stat for Coef: 1093.3646
# future-week: 1 look-back windows (days): 56
# Coef: 0.9506
# T-stat for Coef: 1156.8723
# future-week: 2 look-back windows (days): 7
# Coef: 0.7511
# T-stat for Coef: 285.1795
# future-week: 2 look-back windows (days): 14
# Coef: 0.7385
# T-stat for Coef: 279.6986
# future-week: 2 look-back windows (days): 21
# Coef: 0.8084
# T-stat for Coef: 360.5953
# future-week: 2 look-back windows (days): 28
# Coef: 0.8429
# T-stat for Coef: 421.3752
# future-week: 2 look-back windows (days): 35
# Coef: 0.8644
# T-stat for Coef: 468.9161
# future-week: 2 look-back windows (days): 42
# Coef: 0.8822
# T-stat for Coef: 509.0346
# future-week: 2 look-back windows (days): 49
# Coef: 0.8994
# T-stat for Coef: 556.4839
# future-week: 2 look-back windows (days): 56
# Coef: 0.9084
# T-stat for Coef: 586.4477
# future-week: 3 look-back windows (days): 7
# Coef: 0.7535
# T-stat for Coef: 234.4169
# future-week: 3 look-back windows (days): 14
# Coef: 0.7467
# T-stat for Coef: 233.9246
# future-week: 3 look-back windows (days): 21
# Coef: 0.7338
# T-stat for Coef: 228.8768
# future-week: 3 look-back windows (days): 28
# Coef: 0.7828
# T-stat for Coef: 274.5403
# future-week: 3 look-back windows (days): 35
# Coef: 0.8124
# T-stat for Coef: 308.6898
# future-week: 3 look-back windows (days): 42
# Coef: 0.8352
# T-stat for Coef: 338.4058
# future-week: 3 look-back windows (days): 49
# Coef: 0.8552
# T-stat for Coef: 367.3154
# future-week: 3 look-back windows (days): 56
# Coef: 0.8702
# T-stat for Coef: 391.7622
# future-week: 4 look-back windows (days): 7
# Coef: 0.7537
# T-stat for Coef: 203.9023
# future-week: 4 look-back windows (days): 14
# Coef: 0.7475
# T-stat for Coef: 203.1365
# future-week: 4 look-back windows (days): 21
# Coef: 0.7404
# T-stat for Coef: 202.333
# future-week: 4 look-back windows (days): 28
# Coef: 0.7284
# T-stat for Coef: 198.7903
# future-week: 4 look-back windows (days): 35
# Coef: 0.7669
# T-stat for Coef: 228.2961
# future-week: 4 look-back windows (days): 42
# Coef: 0.7938
# T-stat for Coef: 251.968
# future-week: 4 look-back windows (days): 49
# Coef: 0.8157
# T-stat for Coef: 272.5767
# future-week: 4 look-back windows (days): 56
# Coef: 0.8348
# T-stat for Coef: 291.6183
# future-week: 5 look-back windows (days): 7
# Coef: 0.7577
# T-stat for Coef: 184.2667
# future-week: 5 look-back windows (days): 14
# Coef: 0.7459
# T-stat for Coef: 180.6878
# future-week: 5 look-back windows (days): 21
# Coef: 0.7392
# T-stat for Coef: 180.474
# future-week: 5 look-back windows (days): 28
# Coef: 0.7329
# T-stat for Coef: 179.8059
# future-week: 5 look-back windows (days): 35
# Coef: 0.7205
# T-stat for Coef: 175.1132
# future-week: 5 look-back windows (days): 42
# Coef: 0.7571
# T-stat for Coef: 197.9065
# future-week: 5 look-back windows (days): 49
# Coef: 0.7812
# T-stat for Coef: 215.0004
# future-week: 5 look-back windows (days): 56
# Coef: 0.8018
# T-stat for Coef: 231.2939
# future-week: 6 look-back windows (days): 7
# Coef: 0.7568
# T-stat for Coef: 167.6899
# future-week: 6 look-back windows (days): 14
# Coef: 0.7542
# T-stat for Coef: 168.6493
# future-week: 6 look-back windows (days): 21
# Coef: 0.749
# T-stat for Coef: 168.4863
# future-week: 6 look-back windows (days): 28
# Coef: 0.735
# T-stat for Coef: 164.9137
# future-week: 6 look-back windows (days): 35
# Coef: 0.7262
# T-stat for Coef: 162.8148
# future-week: 6 look-back windows (days): 42
# Coef: 0.7213
# T-stat for Coef: 161.6687
# future-week: 6 look-back windows (days): 49
# Coef: 0.7466
# T-stat for Coef: 176.4276
# future-week: 6 look-back windows (days): 56
# Coef: 0.7687
# T-stat for Coef: 189.9409
# future-week: 7 look-back windows (days): 7
# Coef: 0.7596
# T-stat for Coef: 156.237
# future-week: 7 look-back windows (days): 14
# Coef: 0.7556
# T-stat for Coef: 157.155
# future-week: 7 look-back windows (days): 21
# Coef: 0.7506
# T-stat for Coef: 157.1991
# future-week: 7 look-back windows (days): 28
# Coef: 0.7444
# T-stat for Coef: 156.7716
# future-week: 7 look-back windows (days): 35
# Coef: 0.7338
# T-stat for Coef: 153.085
# future-week: 7 look-back windows (days): 42
# Coef: 0.7256
# T-stat for Coef: 150.323
# future-week: 7 look-back windows (days): 49
# Coef: 0.7156
# T-stat for Coef: 146.3494
# future-week: 7 look-back windows (days): 56
# Coef: 0.7437
# T-stat for Coef: 160.0755
# future-week: 8 look-back windows (days): 7
# Coef: 0.7691
# T-stat for Coef: 151.9138
# future-week: 8 look-back windows (days): 14
# Coef: 0.7605
# T-stat for Coef: 150.2711
# future-week: 8 look-back windows (days): 21
# Coef: 0.7525
# T-stat for Coef: 149.4119
# future-week: 8 look-back windows (days): 28
# Coef: 0.7433
# T-stat for Coef: 147.1512
# future-week: 8 look-back windows (days): 35
# Coef: 0.7324
# T-stat for Coef: 145.3759
# future-week: 8 look-back windows (days): 42
# Coef: 0.7297
# T-stat for Coef: 145.0622
# future-week: 8 look-back windows (days): 49
# Coef: 0.7286
# T-stat for Coef: 144.708
# future-week: 8 look-back windows (days): 56
# Coef: 0.7226
# T-stat for Coef: 142.7536

# %% [markdown]
# Only Major coins

# %%
# constant 있는 결과
holding = [1,2,3,4,5,6,7,8]
look_back_list = [i * 7 for i in holding]

for reb in holding:
    for look_back in look_back_list:
        reb = str(reb)
        #for day in days_lst:
        pct_df = make_group_percentile(
            price_df = data_pp.price_df,
            weekly_rtn_df = data_pp.weekly_rtn_df, 
            mask_df = data_pp.mask,
            n_group = 5,
            day_of_week = 'FRI',
            coin_group=20,
            look_back=look_back,
            reb=reb
        )
        
        mktcap_pp = data_pp.mktcap_df.loc[pct_df.index]
        mask_pp = data_pp.mask.loc[pct_df.index]

        # Capped 씌워주기 (전체에서 Cap을 씌우고, 그룹을 나눠준다)
        mktcap_df_used = mktcap_pp.copy() * mask_pp
        mktcap_rank = mktcap_df_used.rank(1)
        rank_thresh = (mktcap_rank.max(1) * 0.95).dropna().map(int) 

        # index alignment
        mktcap_rank = mktcap_rank.loc[rank_thresh.index]
        coin_thresh_series = mktcap_rank.eq(rank_thresh, axis=0).idxmax(axis=1) # values가 타겟 코인의 컬럼명, index가 날짜인 시리즈
        filtered = mktcap_rank.apply(lambda x: x > rank_thresh, axis=0).replace({True:1, False:np.nan})
        
        pct_df = (pct_df * filtered)
        d = pd.concat([pct_df.melt(), pct_df.shift(-1).melt()], axis=1).iloc[:, [0,1,3]].dropna()
        d.columns = ['coin_id', 'x', 'y']
    
        #all_df = pd.concat([all_df, d])
    
        ols =  sm.OLS(d.y, sm.add_constant(d.x))
        result = ols.fit()
        print("future-week:", reb, "look-back windows (days):",  look_back)
        print(f'Constant: {result.params[0].round(4)},  Coef: {result.params[1].round(4)}')
        print(f'T-stat for Constant: {result.tvalues[0].round(4)}, T-stat for Coef: {result.tvalues[1].round(4)}')
# Out:
# future-week: 1 look-back windows (days): 7
# Constant: 0.532,  Coef: 0.0392
# T-stat for Constant: 67.071, T-stat for Coef: 3.0326
# future-week: 1 look-back windows (days): 14
# Constant: 0.2674,  Coef: 0.525
# T-stat for Constant: 38.5715, T-stat for Coef: 47.4433
# future-week: 1 look-back windows (days): 21
# Constant: 0.1897,  Coef: 0.6663
# T-stat for Constant: 30.9713, T-stat for Coef: 68.7972
# future-week: 1 look-back windows (days): 28
# Constant: 0.1443,  Coef: 0.7466
# T-stat for Constant: 26.3206, T-stat for Coef: 86.6547
# future-week: 1 look-back windows (days): 35
# Constant: 0.1197,  Coef: 0.7892
# T-stat for Constant: 23.5241, T-stat for Coef: 99.1205
# future-week: 1 look-back windows (days): 42
# Constant: 0.0952,  Coef: 0.8317
# T-stat for Constant: 20.5138, T-stat for Coef: 114.8637
# future-week: 1 look-back windows (days): 49
# Constant: 0.0843,  Coef: 0.8514
# T-stat for Constant: 19.1468, T-stat for Coef: 124.5374
# future-week: 1 look-back windows (days): 56
# Constant: 0.0759,  Coef: 0.8658
# T-stat for Constant: 17.9041, T-stat for Coef: 132.1422
# future-week: 2 look-back windows (days): 7
# Constant: 0.5176,  Coef: 0.0564
# T-stat for Constant: 45.9708, T-stat for Coef: 3.0565
# future-week: 2 look-back windows (days): 14
# Constant: 0.5124,  Coef: 0.0915
# T-stat for Constant: 44.3062, T-stat for Coef: 4.9637
# future-week: 2 look-back windows (days): 21
# Constant: 0.3649,  Coef: 0.3545
# T-stat for Constant: 33.4648, T-stat for Coef: 20.4969
# future-week: 2 look-back windows (days): 28
# Constant: 0.2878,  Coef: 0.4976
# T-stat for Constant: 27.9577, T-stat for Coef: 30.9682
# future-week: 2 look-back windows (days): 35
# Constant: 0.2391,  Coef: 0.58
# T-stat for Constant: 24.7165, T-stat for Coef: 38.4743
# future-week: 2 look-back windows (days): 42
# Constant: 0.2023,  Coef: 0.6467
# T-stat for Constant: 22.1655, T-stat for Coef: 45.7383
# future-week: 2 look-back windows (days): 49
# Constant: 0.174,  Coef: 0.6946
# T-stat for Constant: 20.1846, T-stat for Coef: 52.0097
# future-week: 2 look-back windows (days): 56
# Constant: 0.1547,  Coef: 0.7289
# T-stat for Constant: 18.6356, T-stat for Coef: 57.1189
# future-week: 3 look-back windows (days): 7
# Constant: 0.5575,  Coef: -0.0023
# T-stat for Constant: 40.136, T-stat for Coef: -0.0998
# future-week: 3 look-back windows (days): 14
# Constant: 0.5615,  Coef: -0.0082
# T-stat for Constant: 40.0203, T-stat for Coef: -0.3596
# future-week: 3 look-back windows (days): 21
# Constant: 0.559,  Coef: 0.026
# T-stat for Constant: 38.6155, T-stat for Coef: 1.1411
# future-week: 3 look-back windows (days): 28
# Constant: 0.4564,  Coef: 0.2024
# T-stat for Constant: 32.1394, T-stat for Coef: 9.0648
# future-week: 3 look-back windows (days): 35
# Constant: 0.3699,  Coef: 0.3524
# T-stat for Constant: 27.2262, T-stat for Coef: 16.5137
# future-week: 3 look-back windows (days): 42
# Constant: 0.3128,  Coef: 0.4606
# T-stat for Constant: 23.8183, T-stat for Coef: 22.676
# future-week: 3 look-back windows (days): 49
# Constant: 0.2813,  Coef: 0.5121
# T-stat for Constant: 22.1352, T-stat for Coef: 26.01
# future-week: 3 look-back windows (days): 56
# Constant: 0.2428,  Coef: 0.5757
# T-stat for Constant: 20.139, T-stat for Coef: 30.7406
# future-week: 4 look-back windows (days): 7
# Constant: 0.5587,  Coef: -0.0212
# T-stat for Constant: 35.0806, T-stat for Coef: -0.804
# future-week: 4 look-back windows (days): 14
# Constant: 0.5722,  Coef: -0.0114
# T-stat for Constant: 34.7853, T-stat for Coef: -0.434
# future-week: 4 look-back windows (days): 21
# Constant: 0.5646,  Coef: 0.0097
# T-stat for Constant: 33.6315, T-stat for Coef: 0.3671
# future-week: 4 look-back windows (days): 28
# Constant: 0.5738,  Coef: 0.0068
# T-stat for Constant: 33.7392, T-stat for Coef: 0.2564
# future-week: 4 look-back windows (days): 35
# Constant: 0.4873,  Coef: 0.1523
# T-stat for Constant: 28.9384, T-stat for Coef: 5.8255
# future-week: 4 look-back windows (days): 42
# Constant: 0.4211,  Coef: 0.2738
# T-stat for Constant: 25.1842, T-stat for Coef: 10.6657
# future-week: 4 look-back windows (days): 49
# Constant: 0.363,  Coef: 0.377
# T-stat for Constant: 22.5876, T-stat for Coef: 15.3099
# future-week: 4 look-back windows (days): 56
# Constant: 0.3394,  Coef: 0.4188
# T-stat for Constant: 21.3359, T-stat for Coef: 17.2819
# future-week: 5 look-back windows (days): 7
# Constant: 0.6339,  Coef: -0.1025
# T-stat for Constant: 33.1507, T-stat for Coef: -3.3915
# future-week: 5 look-back windows (days): 14
# Constant: 0.6517,  Coef: -0.122
# T-stat for Constant: 34.0107, T-stat for Coef: -4.0715
# future-week: 5 look-back windows (days): 21
# Constant: 0.6283,  Coef: -0.0693
# T-stat for Constant: 32.4068, T-stat for Coef: -2.316
# future-week: 5 look-back windows (days): 28
# Constant: 0.6338,  Coef: -0.0785
# T-stat for Constant: 32.7169, T-stat for Coef: -2.6371
# future-week: 5 look-back windows (days): 35
# Constant: 0.606,  Coef: -0.0367
# T-stat for Constant: 30.8328, T-stat for Coef: -1.2208
# future-week: 5 look-back windows (days): 42
# Constant: 0.5309,  Coef: 0.1043
# T-stat for Constant: 26.9351, T-stat for Coef: 3.4808
# future-week: 5 look-back windows (days): 49
# Constant: 0.4806,  Coef: 0.1891
# T-stat for Constant: 24.6216, T-stat for Coef: 6.3798
# future-week: 5 look-back windows (days): 56
# Constant: 0.4193,  Coef: 0.292
# T-stat for Constant: 22.1044, T-stat for Coef: 10.1408
# future-week: 6 look-back windows (days): 7
# Constant: 0.5669,  Coef: -0.0125
# T-stat for Constant: 28.1022, T-stat for Coef: -0.3833
# future-week: 6 look-back windows (days): 14
# Constant: 0.5405,  Coef: 0.0503
# T-stat for Constant: 26.4667, T-stat for Coef: 1.5418
# future-week: 6 look-back windows (days): 21
# Constant: 0.5696,  Coef: 0.0088
# T-stat for Constant: 27.0199, T-stat for Coef: 0.2651
# future-week: 6 look-back windows (days): 28
# Constant: 0.6256,  Coef: -0.0838
# T-stat for Constant: 29.8063, T-stat for Coef: -2.5493
# future-week: 6 look-back windows (days): 35
# Constant: 0.6068,  Coef: -0.0593
# T-stat for Constant: 29.2011, T-stat for Coef: -1.8149
# future-week: 6 look-back windows (days): 42
# Constant: 0.6216,  Coef: -0.0514
# T-stat for Constant: 28.8739, T-stat for Coef: -1.5632
# future-week: 6 look-back windows (days): 49
# Constant: 0.5626,  Coef: 0.0436
# T-stat for Constant: 26.2888, T-stat for Coef: 1.3282
# future-week: 6 look-back windows (days): 56
# Constant: 0.5041,  Coef: 0.1385
# T-stat for Constant: 23.6191, T-stat for Coef: 4.23
# future-week: 7 look-back windows (days): 7
# Constant: 0.5678,  Coef: -0.0165
# T-stat for Constant: 25.5219, T-stat for Coef: -0.4608
# future-week: 7 look-back windows (days): 14
# Constant: 0.5905,  Coef: -0.0514
# T-stat for Constant: 26.164, T-stat for Coef: -1.4216
# future-week: 7 look-back windows (days): 21
# Constant: 0.671,  Coef: -0.143
# T-stat for Constant: 28.8106, T-stat for Coef: -3.9852
# future-week: 7 look-back windows (days): 28
# Constant: 0.652,  Coef: -0.1194
# T-stat for Constant: 27.9382, T-stat for Coef: -3.3154
# future-week: 7 look-back windows (days): 35
# Constant: 0.6582,  Coef: -0.1508
# T-stat for Constant: 28.5748, T-stat for Coef: -4.2019
# future-week: 7 look-back windows (days): 42
# Constant: 0.6915,  Coef: -0.162
# T-stat for Constant: 29.1051, T-stat for Coef: -4.4972
# future-week: 7 look-back windows (days): 49
# Constant: 0.7027,  Coef: -0.1739
# T-stat for Constant: 29.2082, T-stat for Coef: -4.8054
# future-week: 7 look-back windows (days): 56
# Constant: 0.6179,  Coef: -0.0285
# T-stat for Constant: 25.4873, T-stat for Coef: -0.7829
# future-week: 8 look-back windows (days): 7
# Constant: 0.5671,  Coef: -0.0004
# T-stat for Constant: 24.5897, T-stat for Coef: -0.0116
# future-week: 8 look-back windows (days): 14
# Constant: 0.6014,  Coef: -0.0095
# T-stat for Constant: 24.6151, T-stat for Coef: -0.2509
# future-week: 8 look-back windows (days): 21
# Constant: 0.5855,  Coef: -0.004
# T-stat for Constant: 23.9281, T-stat for Coef: -0.1059
# future-week: 8 look-back windows (days): 28
# Constant: 0.6294,  Coef: -0.0639
# T-stat for Constant: 25.2755, T-stat for Coef: -1.6784
# future-week: 8 look-back windows (days): 35
# Constant: 0.6099,  Coef: -0.0441
# T-stat for Constant: 24.7884, T-stat for Coef: -1.1698
# future-week: 8 look-back windows (days): 42
# Constant: 0.6028,  Coef: -0.0348
# T-stat for Constant: 24.0507, T-stat for Coef: -0.9093
# future-week: 8 look-back windows (days): 49
# Constant: 0.6214,  Coef: -0.0496
# T-stat for Constant: 24.5909, T-stat for Coef: -1.3005
# future-week: 8 look-back windows (days): 56
# Constant: 0.6335,  Coef: -0.0626
# T-stat for Constant: 24.7886, T-stat for Coef: -1.6378

# %% [markdown]
# Below 5 percent

# %%
# constant 있는 결과
holding = [1,2,3,4,5,6,7,8]
look_back_list = [i * 7 for i in holding]

for reb in holding:
    for look_back in look_back_list:
        reb = str(reb)
        #for day in days_lst:
        pct_df = make_group_percentile(
            price_df = data_pp.price_df,
            weekly_rtn_df = data_pp.weekly_rtn_df, 
            mask_df = data_pp.mask,
            n_group = 5,
            day_of_week = 'FRI',
            coin_group=20,
            look_back=look_back,
            reb=reb
        )
        
        mktcap_pp = data_pp.mktcap_df.loc[pct_df.index]
        mask_pp = data_pp.mask.loc[pct_df.index]

        # Capped 씌워주기 (전체에서 Cap을 씌우고, 그룹을 나눠준다)
        mktcap_df_used = mktcap_pp.copy() * mask_pp
        mktcap_rank = mktcap_df_used.rank(1)
        rank_thresh = (mktcap_rank.max(1) * 0.95).dropna().map(int) 

        # index alignment
        mktcap_rank = mktcap_rank.loc[rank_thresh.index]
        coin_thresh_series = mktcap_rank.eq(rank_thresh, axis=0).idxmax(axis=1) # values가 타겟 코인의 컬럼명, index가 날짜인 시리즈
        filtered = mktcap_rank.apply(lambda x: x <= rank_thresh, axis=0).replace({True:1, False:np.nan})
        
        pct_df = (pct_df * filtered)
        d = pd.concat([pct_df.melt(), pct_df.shift(-1).melt()], axis=1).iloc[:, [0,1,3]].dropna()
        d.columns = ['coin_id', 'x', 'y']
    
        #all_df = pd.concat([all_df, d])
    
        ols =  sm.OLS(d.y, sm.add_constant(d.x))
        result = ols.fit()
        print("future-week:", reb, "look-back windows (days):",  look_back)
        print(f'Constant: {result.params[0].round(4)},  Coef: {result.params[1].round(4)}')
        print(f'T-stat for Constant: {result.tvalues[0].round(4)}, T-stat for Coef: {result.tvalues[1].round(4)}')
# Out:
# future-week: 1 look-back windows (days): 7
# Constant: 0.5077,  Coef: -0.0234
# T-stat for Constant: 293.0515, T-stat for Coef: -7.8163
# future-week: 1 look-back windows (days): 14
# Constant: 0.2762,  Coef: 0.4347
# T-stat for Constant: 176.9241, T-stat for Coef: 161.6179
# future-week: 1 look-back windows (days): 21
# Constant: 0.1953,  Coef: 0.5944
# T-stat for Constant: 139.6793, T-stat for Coef: 247.3697
# future-week: 1 look-back windows (days): 28
# Constant: 0.1481,  Coef: 0.6878
# T-stat for Constant: 117.0694, T-stat for Coef: 316.5861
# future-week: 1 look-back windows (days): 35
# Constant: 0.1215,  Coef: 0.7441
# T-stat for Constant: 104.4101, T-stat for Coef: 371.1785
# future-week: 1 look-back windows (days): 42
# Constant: 0.1034,  Coef: 0.7813
# T-stat for Constant: 95.1701, T-stat for Coef: 416.4355
# future-week: 1 look-back windows (days): 49
# Constant: 0.0903,  Coef: 0.8083
# T-stat for Constant: 88.0782, T-stat for Coef: 455.7856
# future-week: 1 look-back windows (days): 56
# Constant: 0.0808,  Coef: 0.8283
# T-stat for Constant: 82.5572, T-stat for Coef: 489.3525
# future-week: 2 look-back windows (days): 7
# Constant: 0.4953,  Coef: 0.0069
# T-stat for Constant: 198.4879, T-stat for Coef: 1.6107
# future-week: 2 look-back windows (days): 14
# Constant: 0.5066,  Coef: -0.0235
# T-stat for Constant: 202.3642, T-stat for Coef: -5.4832
# future-week: 2 look-back windows (days): 21
# Constant: 0.3505,  Coef: 0.2814
# T-stat for Constant: 144.7766, T-stat for Coef: 68.2703
# future-week: 2 look-back windows (days): 28
# Constant: 0.271,  Coef: 0.4393
# T-stat for Constant: 119.6162, T-stat for Coef: 113.7996
# future-week: 2 look-back windows (days): 35
# Constant: 0.2242,  Coef: 0.535
# T-stat for Constant: 105.181, T-stat for Coef: 147.0123
# future-week: 2 look-back windows (days): 42
# Constant: 0.1949,  Coef: 0.5936
# T-stat for Constant: 96.242, T-stat for Coef: 171.0348
# future-week: 2 look-back windows (days): 49
# Constant: 0.1671,  Coef: 0.6495
# T-stat for Constant: 87.416, T-stat for Coef: 197.7295
# future-week: 2 look-back windows (days): 56
# Constant: 0.1516,  Coef: 0.6809
# T-stat for Constant: 82.2471, T-stat for Coef: 214.67
# future-week: 3 look-back windows (days): 7
# Constant: 0.4966,  Coef: 0.0075
# T-stat for Constant: 159.5432, T-stat for Coef: 1.413
# future-week: 3 look-back windows (days): 14
# Constant: 0.4978,  Coef: 0.0019
# T-stat for Constant: 158.91, T-stat for Coef: 0.3558
# future-week: 3 look-back windows (days): 21
# Constant: 0.5137,  Coef: -0.0339
# T-stat for Constant: 163.858, T-stat for Coef: -6.3616
# future-week: 3 look-back windows (days): 28
# Constant: 0.3938,  Coef: 0.1995
# T-stat for Constant: 127.7324, T-stat for Coef: 38.1905
# future-week: 3 look-back windows (days): 35
# Constant: 0.3259,  Coef: 0.3343
# T-stat for Constant: 109.771, T-stat for Coef: 66.328
# future-week: 3 look-back windows (days): 42
# Constant: 0.2792,  Coef: 0.4265
# T-stat for Constant: 98.1858, T-stat for Coef: 88.0937
# future-week: 3 look-back windows (days): 49
# Constant: 0.2429,  Coef: 0.4991
# T-stat for Constant: 89.2756, T-stat for Coef: 107.4135
# future-week: 3 look-back windows (days): 56
# Constant: 0.2181,  Coef: 0.5482
# T-stat for Constant: 83.0858, T-stat for Coef: 121.9059
# future-week: 4 look-back windows (days): 7
# Constant: 0.5034,  Coef: 0.0013
# T-stat for Constant: 137.0065, T-stat for Coef: 0.215
# future-week: 4 look-back windows (days): 14
# Constant: 0.5046,  Coef: -0.0055
# T-stat for Constant: 137.1034, T-stat for Coef: -0.8731
# future-week: 4 look-back windows (days): 21
# Constant: 0.5075,  Coef: -0.0159
# T-stat for Constant: 137.5669, T-stat for Coef: -2.5439
# future-week: 4 look-back windows (days): 28
# Constant: 0.5186,  Coef: -0.0423
# T-stat for Constant: 140.7737, T-stat for Coef: -6.782
# future-week: 4 look-back windows (days): 35
# Constant: 0.4222,  Coef: 0.1469
# T-stat for Constant: 115.3366, T-stat for Coef: 23.6935
# future-week: 4 look-back windows (days): 42
# Constant: 0.3611,  Coef: 0.266
# T-stat for Constant: 101.2223, T-stat for Coef: 43.9594
# future-week: 4 look-back windows (days): 49
# Constant: 0.319,  Coef: 0.3492
# T-stat for Constant: 91.9206, T-stat for Coef: 59.205
# future-week: 4 look-back windows (days): 56
# Constant: 0.2842,  Coef: 0.4175
# T-stat for Constant: 84.4763, T-stat for Coef: 72.755
# future-week: 5 look-back windows (days): 7
# Constant: 0.4978,  Coef: 0.0119
# T-stat for Constant: 120.6398, T-stat for Coef: 1.6776
# future-week: 5 look-back windows (days): 14
# Constant: 0.5175,  Coef: -0.0242
# T-stat for Constant: 124.4137, T-stat for Coef: -3.4262
# future-week: 5 look-back windows (days): 21
# Constant: 0.5209,  Coef: -0.0373
# T-stat for Constant: 125.4422, T-stat for Coef: -5.2867
# future-week: 5 look-back windows (days): 28
# Constant: 0.5236,  Coef: -0.0417
# T-stat for Constant: 125.6729, T-stat for Coef: -5.9127
# future-week: 5 look-back windows (days): 35
# Constant: 0.5332,  Coef: -0.0636
# T-stat for Constant: 127.582, T-stat for Coef: -8.9914
# future-week: 5 look-back windows (days): 42
# Constant: 0.444,  Coef: 0.1078
# T-stat for Constant: 106.4383, T-stat for Coef: 15.2588
# future-week: 5 look-back windows (days): 49
# Constant: 0.3924,  Coef: 0.2084
# T-stat for Constant: 95.5231, T-stat for Coef: 29.8878
# future-week: 5 look-back windows (days): 56
# Constant: 0.3489,  Coef: 0.2911
# T-stat for Constant: 86.9791, T-stat for Coef: 42.6276
# future-week: 6 look-back windows (days): 7
# Constant: 0.5026,  Coef: 0.0017
# T-stat for Constant: 109.7967, T-stat for Coef: 0.2187
# future-week: 6 look-back windows (days): 14
# Constant: 0.501,  Coef: -0.001
# T-stat for Constant: 110.0377, T-stat for Coef: -0.1333
# future-week: 6 look-back windows (days): 21
# Constant: 0.5022,  Coef: -0.0045
# T-stat for Constant: 110.1971, T-stat for Coef: -0.5824
# future-week: 6 look-back windows (days): 28
# Constant: 0.5193,  Coef: -0.0364
# T-stat for Constant: 113.6528, T-stat for Coef: -4.6725
# future-week: 6 look-back windows (days): 35
# Constant: 0.5262,  Coef: -0.0471
# T-stat for Constant: 114.3606, T-stat for Coef: -6.0463
# future-week: 6 look-back windows (days): 42
# Constant: 0.5313,  Coef: -0.057
# T-stat for Constant: 115.0496, T-stat for Coef: -7.3092
# future-week: 6 look-back windows (days): 49
# Constant: 0.4652,  Coef: 0.0683
# T-stat for Constant: 100.7377, T-stat for Coef: 8.7465
# future-week: 6 look-back windows (days): 56
# Constant: 0.4128,  Coef: 0.1657
# T-stat for Constant: 90.6967, T-stat for Coef: 21.4339
# future-week: 7 look-back windows (days): 7
# Constant: 0.5084,  Coef: -0.0025
# T-stat for Constant: 101.4707, T-stat for Coef: -0.2928
# future-week: 7 look-back windows (days): 14
# Constant: 0.5056,  Coef: 0.0047
# T-stat for Constant: 100.61, T-stat for Coef: 0.5504
# future-week: 7 look-back windows (days): 21
# Constant: 0.5026,  Coef: 0.0041
# T-stat for Constant: 100.2682, T-stat for Coef: 0.4751
# future-week: 7 look-back windows (days): 28
# Constant: 0.5116,  Coef: -0.0092
# T-stat for Constant: 101.2357, T-stat for Coef: -1.0725
# future-week: 7 look-back windows (days): 35
# Constant: 0.5285,  Coef: -0.0406
# T-stat for Constant: 103.9361, T-stat for Coef: -4.7498
# future-week: 7 look-back windows (days): 42
# Constant: 0.5363,  Coef: -0.0606
# T-stat for Constant: 105.6572, T-stat for Coef: -7.0808
# future-week: 7 look-back windows (days): 49
# Constant: 0.554,  Coef: -0.0949
# T-stat for Constant: 109.3946, T-stat for Coef: -11.1115
# future-week: 7 look-back windows (days): 56
# Constant: 0.485,  Coef: 0.0353
# T-stat for Constant: 95.1359, T-stat for Coef: 4.1022
# future-week: 8 look-back windows (days): 7
# Constant: 0.4918,  Coef: 0.0402
# T-stat for Constant: 91.8821, T-stat for Coef: 4.3975
# future-week: 8 look-back windows (days): 14
# Constant: 0.5044,  Coef: 0.0106
# T-stat for Constant: 94.2313, T-stat for Coef: 1.1642
# future-week: 8 look-back windows (days): 21
# Constant: 0.511,  Coef: -0.005
# T-stat for Constant: 95.0275, T-stat for Coef: -0.5442
# future-week: 8 look-back windows (days): 28
# Constant: 0.5173,  Coef: -0.0199
# T-stat for Constant: 96.3487, T-stat for Coef: -2.1821
# future-week: 8 look-back windows (days): 35
# Constant: 0.5248,  Coef: -0.0338
# T-stat for Constant: 97.4284, T-stat for Coef: -3.7101
# future-week: 8 look-back windows (days): 42
# Constant: 0.5224,  Coef: -0.029
# T-stat for Constant: 96.4219, T-stat for Coef: -3.176
# future-week: 8 look-back windows (days): 49
# Constant: 0.5263,  Coef: -0.0373
# T-stat for Constant: 97.1189, T-stat for Coef: -4.085
# future-week: 8 look-back windows (days): 56
# Constant: 0.5329,  Coef: -0.0512
# T-stat for Constant: 98.205, T-stat for Coef: -5.6039
